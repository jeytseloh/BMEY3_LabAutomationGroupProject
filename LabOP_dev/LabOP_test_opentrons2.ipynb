# %%
import opentrons.simulate as simulate
from opentrons.protocols import bundle
import io
import sys

import os
import tempfile
import sbol3
import labop
import tyto
import uml
import json
import rdflib as rdfl
from IPython.display import Markdown, IFrame
# %matplotlib inline
from IPython.display import Image

from labop.execution_engine import ExecutionEngine
# from labop_check.labop_check import check_doc
from labop_convert.markdown.markdown_specialization import MarkdownSpecialization
from labop_convert.opentrons.opentrons_specialization import OT2Specialization
from labop.utils.opentrons import run_ot2_sim, make_demo_script

out_dir = os.path.join(os.path.abspath(""), "out")
if not os.path.exists(out_dir):
    os.mkdir(out_dir)

# %load_ext autoreload
# %autoreload 2
# Out:
# /Users/jeytse/BMEY3_LabAutomationGroupProject/labOP_env/lib/python3.10/site-packages/sbol3/object.py:70: UserWarning: Using a default namespace. To set a namespace use set_namespace()
#   warnings.warn('Using a default namespace.'

# %%
#############################################
# set up the document
print('Setting up document')
doc = sbol3.Document()
sbol3.set_namespace('https://bbn.com/scratch/')

#############################################
# Import the primitive libraries
print('Importing libraries')
labop.import_library('liquid_handling')
print('... Imported liquid handling')
labop.import_library('plate_handling')
print('... Imported plate handling')
labop.import_library('spectrophotometry')
print('... Imported spectrophotometry')
labop.import_library('sample_arrays')
print('... Imported sample arrays')

protocol = labop.Protocol("OT2_demo")
protocol.name = "OT2 demo"
doc.add(protocol)

CONT_NS = rdfl.Namespace('https://sift.net/container-ontology/container-ontology#')
OM_NS = rdfl.Namespace('http://www.ontology-of-units-of-measure.org/resource/om-2/')
PREFIX_MAP = json.dumps({"cont": CONT_NS, "om": OM_NS})

# plate = protocol.load_labware('corning_96_wellplate_360ul_flat', location='1')
plate_spec = labop.ContainerSpec('sample_plate', name='sample plate', 
                                 queryString='cont:Corning96WellPlate360uLFlat', 
                                 prefixMap=PREFIX_MAP)
plate = protocol.primitive_step('EmptyContainer', specification=plate_spec)
load_plate = protocol.primitive_step('LoadRackOnInstrument', rack=plate_spec, coordinates='1')

# tiprack = protocol.load_labware('opentrons_96_tiprack_300ul', location='2')
tiprack_spec = labop.ContainerSpec('tiprack', queryString='cont:Opentrons96TipRack300uL', prefixMap=PREFIX_MAP)
tiprack = protocol.primitive_step('LoadRackOnInstrument', rack=tiprack_spec, coordinates='2')

# left_pipette = protocol.load_instrument(
#          'p300_single', mount='left', tip_racks=[tiprack])
p300 = sbol3.Agent('p300_single', name='P300 Single')
doc.add(p300)
left_pipette = protocol.primitive_step('ConfigureRobot', instrument=p300, mount="left")

# left_pipette.pick_up_tip()
# left_pipette.aspirate(100, plate['A1'])
# left_pipette.dispense(100, plate['B2'])
# left_pipette.drop_tip()
source_well = protocol.primitive_step('PlateCoordinates', source=plate.output_pin('samples'), coordinates="A1")
dest_well = protocol.primitive_step('PlateCoordinates', source=plate.output_pin('samples'), coordinates="B2")
pip1 = protocol.primitive_step("Transfer", 
                               source=source_well.output_pin('samples'), 
                               destination=dest_well.output_pin('samples'), 
                               amount=sbol3.Measure(100, tyto.OM.microliter)
                               )
protocol.to_dot().render(filename=os.path.join(out_dir, protocol.display_name), format="png")



Image(os.path.join(out_dir, protocol.display_name+".png"))
# Out:
# Setting up document
# Importing libraries
# ... Imported liquid handling
# ... Imported plate handling
# ... Imported spectrophotometry
# ... Imported sample arrays

# %%
filename=os.path.join(out_dir, "ot2_demo_labop")
automated_script = filename+".py"
agent = sbol3.Agent("ot2_machine", name='OT2 machine')
ee = ExecutionEngine(specializations=[OT2Specialization(filename)])
parameter_values = []
execution = ee.execute(protocol, agent, id="test_execution")

#v = doc.validate()
#assert len(v) == 0, "".join(f'\n {e}' for e in v)

doc.write(os.path.join(out_dir, 'ot2_demo.ttl'), file_format='ttl')
# Out:
# WARNING:/Users/jeytse/BMEY3_LabAutomationGroupProject/labOP_env/lib/python3.10/site-packages/labop_convert/behavior_specialization.py:'ContainerSpec' object has no attribute 'addl_conditions'
# WARNING:/Users/jeytse/BMEY3_LabAutomationGroupProject/labOP_env/lib/python3.10/site-packages/labop_convert/behavior_specialization.py:Cannot resolve container specification using remote ontology server. Defaulting to static ontology copy
# WARNING:/Users/jeytse/BMEY3_LabAutomationGroupProject/labOP_env/lib/python3.10/site-packages/labop_convert/behavior_specialization.py:'ContainerSpec' object has no attribute 'addl_conditions'
# WARNING:/Users/jeytse/BMEY3_LabAutomationGroupProject/labOP_env/lib/python3.10/site-packages/labop_convert/behavior_specialization.py:Cannot resolve container specification using remote ontology server. Defaulting to static ontology copy
# WARNING:/Users/jeytse/BMEY3_LabAutomationGroupProject/labOP_env/lib/python3.10/site-packages/labop_convert/behavior_specialization.py:'ContainerSpec' object has no attribute 'addl_conditions'
# WARNING:/Users/jeytse/BMEY3_LabAutomationGroupProject/labOP_env/lib/python3.10/site-packages/labop_convert/behavior_specialization.py:Cannot resolve container specification using remote ontology server. Defaulting to static ontology copy
# WARNING:/Users/jeytse/BMEY3_LabAutomationGroupProject/labOP_env/lib/python3.10/site-packages/labop_convert/behavior_specialization.py:'ContainerSpec' object has no attribute 'addl_conditions'
# WARNING:/Users/jeytse/BMEY3_LabAutomationGroupProject/labOP_env/lib/python3.10/site-packages/labop_convert/behavior_specialization.py:Cannot resolve container specification using remote ontology server. Defaulting to static ontology copy
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[3], line 6
#       4 ee = ExecutionEngine(specializations=[OT2Specialization(filename)])
#       5 parameter_values = []
# ----> 6 execution = ee.execute(protocol, agent, id="test_execution")
#       8 #v = doc.validate()
#       9 #assert len(v) == 0, "".join(f'\n {e}' for e in v)
#      11 doc.write(os.path.join(out_dir, 'ot2_demo.ttl'), file_format='ttl')
#
# File ~/BMEY3_LabAutomationGroupProject/labOP_env/lib/python3.10/site-packages/labop/execution_engine.py:170, in ExecutionEngine.execute(self, protocol, agent, parameter_values, id, start_time)
#     168 self.initialize(protocol, agent, id, parameter_values)
#     169 self.run(protocol, start_time=start_time)
# --> 170 self.finalize(protocol)
#     172 return self.ex
#
# File ~/BMEY3_LabAutomationGroupProject/labOP_env/lib/python3.10/site-packages/labop/execution_engine.py:144, in ExecutionEngine.finalize(self, protocol)
#     142 # End specializations
#     143 for specialization in self.specializations:
# --> 144     specialization.on_end(self.ex)
#
# File ~/BMEY3_LabAutomationGroupProject/labOP_env/lib/python3.10/site-packages/labop_convert/opentrons/opentrons_specialization.py:141, in OT2Specialization.on_end(self, ex)
#     139 def on_end(self, ex):
#     140     self.script += self._compile_script()
# --> 141     self.markdown += self._compile_markdown()
#     142     if self.filename:
#     143         with open(self.filename + '.py', 'w') as f:
#
# File ~/BMEY3_LabAutomationGroupProject/labOP_env/lib/python3.10/site-packages/labop_convert/opentrons/opentrons_specialization.py:159, in OT2Specialization._compile_markdown(self)
#     158 def _compile_markdown(self):
# --> 159     markdown = self._materials()
#     160     markdown += '\n## Steps\n'
#     161     for i, step in enumerate(self.markdown_steps):
#
# File ~/BMEY3_LabAutomationGroupProject/labOP_env/lib/python3.10/site-packages/labop_convert/opentrons/opentrons_specialization.py:223, in OT2Specialization._materials(self)
#     221 for container_type, container_name_map in containers.items():
#     222     for container_name, qty in container_name_map.items():
# --> 223         container_str = ContO.get_term_by_uri(container_type)
#     224         if 'TipRack' in container_type:
#     225             text = f'* {container_str}'
#
# File ~/BMEY3_LabAutomationGroupProject/labOP_env/lib/python3.10/site-packages/tyto/tyto.py:109, in Ontology.get_term_by_uri(self, uri)
#     107 sanitized_uri = self._sanitize_uri(uri)
#     108 exception = LookupError(f'No matching term found for {uri}')
# --> 109 term = self._handler('get_term_by_uri', exception, sanitized_uri)
#     110 return Term(self._reverse_sanitize_term(term), sanitized_uri, self)
#
# File ~/BMEY3_LabAutomationGroupProject/labOP_env/lib/python3.10/site-packages/tyto/tyto.py:95, in Ontology._handler(self, method_name, exception, *args)
#      92         LOGGER.error(x)
#      94 if exception:
# ---> 95     raise exception
#      96 return None
#
# LookupError: No matching term found for cont:Corning96WellPlate360uLFlat
